# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.preprocessing import LabelEncoder,StandardScaler,MinMaxScaler
from sklearn.model_selection import StratifiedKFold,GridSearchCV
import lightgbm as lgb
from sklearn.model_selection import cross_val_score,KFold
from sklearn.tree import plot_tree
from matplotlib import pyplot as plt
from sklearn.ensemble import RandomForestClassifier

# %%
train_df = pd.read_csv("./data/mushroom_train.csv", encoding="utf-8")
test_df = pd.read_csv("./data/mushroom_test.csv", encoding="utf-8")

df = pd.concat([train_df, test_df]).reset_index(drop=True)

# %% [markdown]
# 1. 데이터 컬럼 및 개수 파악

# %%
df.shape

# %% [markdown]
# 2. 데이터 컬림 이름 파악

# %%
df.info()

# %% [markdown]
# 3. 데이터 null 갑 파악

# %%
df.isnull().sum()

# %% [markdown]
# 4. 데이터 컬럼 내용 파악  -  불필요한 데이터 삭제

# %%
df.select_dtypes('object').nunique()

# %%
df.nunique()

# %% [markdown]
# 5. 데이터 삭제 :  veil-type : 값 1개여서 지움

# %%
# 값이 1개여서 지움
df = df.drop(['veil-type'],axis=1)

# mushroom_2_trial 에서 plot_importance(model) 에 없어서 지움
# importance에서 10 이하 싹 지움

df = df.drop(['cap-shape','gill-attachment','veil-color','ring-type',
              'stalk-surface-above-ring','stalk-color-above-ring',
              'bruises','stalk-color-below-ring','ring-number',
              'gill-color','cap-color','stalk-shape',],axis=1)

# %% [markdown]
# 6. one hot encoder사용

# %%
# label encoder
# class : { 0 : e , 1 : p , 2 : nan}

label_encoder = LabelEncoder()

name_columns = ['class','cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']

for name in name_columns:
    df[name] = label_encoder.fit_transform(df[name])
df
# Out:
#       mushroom_id  class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0               0      1          5            2          4        1     6
# 1               1      0          5            2          9        1     0
# 2               2      0          0            2          8        1     3
# 3               3      1          5            3          8        1     6
# 4               4      0          5            2          3        0     5
# ...           ...    ...        ...          ...        ...      ...   ...
# 8119         8119      2          3            2          4        0     5
# 8120         8120      2          5            2          4        0     5
# 8121         8121      2          2            2          4        0     5
# 8122         8122      2          3            3          4        0     8
# 8123         8123      2          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  ...  stalk-surface-below-ring  \
# 0                   1             0          1  ...                         2
# 1                   1             0          0  ...                         2
# 2                   1             0          0  ...                         2
# 3                   1             0          1  ...                         2
# 4                   1             1          0  ...                         2
# ...               ...           ...        ...  ...                       ...
# 8119                0             0          0  ...                         2
# 8120                0             0          0  ...                         2
# 8121                0             0          0  ...                         2
# 8122                1             0          1  ...                         1
# 8123                0             0          0  ...                         2
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                          7                       7          0           2
# 1                          7                       7          0           2
# 2                          7                       7          0           2
# 3                          7                       7          0           2
# 4                          7                       7          0           2
# ...                      ...                     ...        ...         ...
# 8119                       5                       5          0           1
# 8120                       5                       5          0           0
# 8121                       5                       5          0           1
# 8122                       7                       7          0           2
# 8123                       5                       5          0           1
#
#       ring-number  ring-type  spore-print-color  population  habitat
# 0               1          4                  2           3        5
# 1               1          4                  3           2        1
# 2               1          4                  3           2        3
# 3               1          4                  2           3        5
# 4               1          0                  3           0        1
# ...           ...        ...                ...         ...      ...
# 8119            1          4                  0           1        2
# 8120            1          4                  0           4        2
# 8121            1          4                  0           1        2
# 8122            1          0                  7           4        2
# 8123            1          4                  4           1        2
#
# [8124 rows x 24 columns]

# %%
minmax_scaler = MinMaxScaler()

name_columns_2 = ['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']


df[['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']] = minmax_scaler.fit_transform(df[['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']])
df
# Out:
#       mushroom_id  class  cap-shape  cap-surface  cap-color  bruises   odor  \
# 0               0      1        1.0     0.666667   0.444444      1.0  0.750
# 1               1      0        1.0     0.666667   1.000000      1.0  0.000
# 2               2      0        0.0     0.666667   0.888889      1.0  0.375
# 3               3      1        1.0     1.000000   0.888889      1.0  0.750
# 4               4      0        1.0     0.666667   0.333333      0.0  0.625
# ...           ...    ...        ...          ...        ...      ...    ...
# 8119         8119      2        0.6     0.666667   0.444444      0.0  0.625
# 8120         8120      2        1.0     0.666667   0.444444      0.0  0.625
# 8121         8121      2        0.4     0.666667   0.444444      0.0  0.625
# 8122         8122      2        0.6     1.000000   0.444444      0.0  1.000
# 8123         8123      2        1.0     0.666667   0.444444      0.0  0.625
#
#       gill-attachment  gill-spacing  gill-size  ...  stalk-surface-below-ring  \
# 0                 1.0           0.0        1.0  ...                  0.666667
# 1                 1.0           0.0        0.0  ...                  0.666667
# 2                 1.0           0.0        0.0  ...                  0.666667
# 3                 1.0           0.0        1.0  ...                  0.666667
# 4                 1.0           1.0        0.0  ...                  0.666667
# ...               ...           ...        ...  ...                       ...
# 8119              0.0           0.0        0.0  ...                  0.666667
# 8120              0.0           0.0        0.0  ...                  0.666667
# 8121              0.0           0.0        0.0  ...                  0.666667
# 8122              1.0           0.0        1.0  ...                  0.333333
# 8123              0.0           0.0        0.0  ...                  0.666667
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                      0.875                   0.875        0.0    0.666667
# 1                      0.875                   0.875        0.0    0.666667
# 2                      0.875                   0.875        0.0    0.666667
# 3                      0.875                   0.875        0.0    0.666667
# 4                      0.875                   0.875        0.0    0.666667
# ...                      ...                     ...        ...         ...
# 8119                   0.625                   0.625        0.0    0.333333
# 8120                   0.625                   0.625        0.0    0.000000
# 8121                   0.625                   0.625        0.0    0.333333
# 8122                   0.875                   0.875        0.0    0.666667
# 8123                   0.625                   0.625        0.0    0.333333
#
#       ring-number  ring-type  spore-print-color  population   habitat
# 0             0.5        1.0              0.250         0.6  0.833333
# 1             0.5        1.0              0.375         0.4  0.166667
# 2             0.5        1.0              0.375         0.4  0.500000
# 3             0.5        1.0              0.250         0.6  0.833333
# 4             0.5        0.0              0.375         0.0  0.166667
# ...           ...        ...                ...         ...       ...
# 8119          0.5        1.0              0.000         0.2  0.333333
# 8120          0.5        1.0              0.000         0.8  0.333333
# 8121          0.5        1.0              0.000         0.2  0.333333
# 8122          0.5        0.0              0.875         0.8  0.333333
# 8123          0.5        1.0              0.500         0.2  0.333333
#
# [8124 rows x 24 columns]

# %%
standard_scaler = StandardScaler()

name_columns_2 = ['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']


df[name_columns_2] = standard_scaler.fit_transform(df[name_columns_2])
df
# Out:
#       mushroom_id  class  cap-shape  cap-surface  cap-color   bruises  \
# 0               0      1   1.029712     0.140128  -0.198250  1.185917
# 1               1      0   1.029712     0.140128   1.765874  1.185917
# 2               2      0  -2.087047     0.140128   1.373049  1.185917
# 3               3      1   1.029712     0.953270   1.373049  1.185917
# 4               4      0   1.029712     0.140128  -0.591075 -0.843230
# ...           ...    ...        ...          ...        ...       ...
# 8119         8119      2  -0.216992     0.140128  -0.198250 -0.843230
# 8120         8120      2   1.029712     0.140128  -0.198250 -0.843230
# 8121         8121      2  -0.840343     0.140128  -0.198250 -0.843230
# 8122         8122      2  -0.216992     0.953270  -0.198250 -0.843230
# 8123         8123      2   1.029712     0.140128  -0.198250 -0.843230
#
#           odor  gill-attachment  gill-spacing  gill-size  ...  \
# 0     0.881938         0.162896     -0.438864   1.494683  ...
# 1    -1.970316         0.162896     -0.438864  -0.669038  ...
# 2    -0.544189         0.162896     -0.438864  -0.669038  ...
# 3     0.881938         0.162896     -0.438864   1.494683  ...
# 4     0.406562         0.162896      2.278612  -0.669038  ...
# ...        ...              ...           ...        ...  ...
# 8119  0.406562        -6.138869     -0.438864  -0.669038  ...
# 8120  0.406562        -6.138869     -0.438864  -0.669038  ...
# 8121  0.406562        -6.138869     -0.438864  -0.669038  ...
# 8122  1.832689         0.162896     -0.438864   1.494683  ...
# 8123  0.406562        -6.138869     -0.438864  -0.669038  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 0                     0.586385                0.622441
# 1                     0.586385                0.622441
# 2                     0.586385                0.622441
# 3                     0.586385                0.622441
# 4                     0.586385                0.622441
# ...                        ...                     ...
# 8119                  0.586385               -0.429288
# 8120                  0.586385               -0.429288
# 8121                  0.586385               -0.429288
# 8122                 -0.893053                0.622441
# 8123                  0.586385               -0.429288
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 0                   0.631991        0.0    0.142037    -0.256132   0.948081
# 1                   0.631991        0.0    0.142037    -0.256132   0.948081
# 2                   0.631991        0.0    0.142037    -0.256132   0.948081
# 3                   0.631991        0.0    0.142037    -0.256132   0.948081
# 4                   0.631991        0.0    0.142037    -0.256132  -1.272216
# ...                      ...        ...         ...          ...        ...
# 8119               -0.416681        0.0   -3.979055    -0.256132   0.948081
# 8120               -0.416681        0.0   -8.100146    -0.256132   0.948081
# 8121               -0.416681        0.0   -3.979055    -0.256132   0.948081
# 8122                0.631991        0.0    0.142037    -0.256132  -1.272216
# 8123               -0.416681        0.0   -3.979055    -0.256132   0.948081
#
#       spore-print-color  population   habitat
# 0             -0.670195   -0.514389  2.030028
# 1             -0.250471   -1.313108 -0.295730
# 2             -0.250471   -1.313108  0.867149
# 3             -0.670195   -0.514389  2.030028
# 4             -0.250471   -2.910546 -0.295730
# ...                 ...         ...       ...
# 8119          -1.509643   -2.111827  0.285710
# 8120          -1.509643    0.284330  0.285710
# 8121          -1.509643   -2.111827  0.285710
# 8122           1.428426    0.284330  0.285710
# 8123           0.169254   -2.111827  0.285710
#
# [8124 rows x 24 columns]

# %% [markdown]
# 7. train, test set 분리

# %%
train_df = df[:6500]
test_df = df[6500:]

# %% [markdown]
# 8. 종속변수, 독립변수 분리

# %%
test_df = test_df.drop(["class"],axis=1)

# %%
x_train = train_df.drop(['mushroom_id','class'],axis=1)
y_train = train_df['class']
x_test = test_df.drop(['mushroom_id'],axis=1)

# %%
model = RandomForestClassifier()

stratified_kf = StratifiedKFold(n_splits=5,shuffle=True,random_state=1234)

param_grid = {
    'n_estimators' : np.arange(1,100,10),
    "max_depth":np.arange(1,10,1)
}

grid_search = GridSearchCV(
    estimator = model,
    param_grid = param_grid,
    cv = stratified_kf
)

# %%
result = grid_search.fit(x_train,y_train)

# %%
result.best_params_
# Out:
# {'max_depth': 6, 'n_estimators': 71}

# %%
result.best_score_
# Out:
# 0.9998461538461537

# %% [markdown]
# 9. Deicision Tree 학습  //  RandomForest 학습

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=6,
    criterion='entropy',
    max_depth=71,
    random_state=1234
)

# %%
kf = StratifiedKFold(n_splits=5,shuffle=True,random_state=1234)

# %%
scores = cross_val_score(model,x_train,y_train,cv=kf)

# %%
scores
# Out:
# array([1.        , 1.        , 0.99923077, 0.99923077, 1.        ])

# %%
scores.mean()
# Out:
# 0.9996923076923077

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=71, n_estimators=6,
#                        random_state=1234)

# %%
y_test_pred = model.predict(x_test)
test_df['class'] = y_test_pred
test_df["class"] = test_df["class"].replace([1,0],["p","e"])

# %%
test_df[['mushroom_id','class']].to_csv('./data/mushroom_submission_9.csv',index=False)

# %% [markdown]
# LightLGB 학습

# %%
y_test_pred = model.predict(x_test)
test_df['class'] = y_test_pred
test_df["class"] = test_df["class"].replace([1,0],["p","e"])

# %%
test_df[['mushroom_id','class']].to_csv('./data/mushroom_submission_4.csv',index=False)
